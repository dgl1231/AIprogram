# %%
from keras.utils import np_utils
from keras.datasets import mnist
from keras.models import Sequential
from keras.layers import Dense, Activation
import keras
import numpy as np

np.random.seed(3)

# %%
# 데이터셋
import tensorflow as tf
(x_train, y_train), (x_test, y_test) = tf.keras.datasets.mnist.load_data();
# Out:
# (60000, 28, 28)
# (60000,)
# (10000, 28, 28)
# (10000,)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-4eab03742a78> in <module>()
#       8 print(y_test.shape);
#       9
# ---> 10 plt.imshow(x_train[0]);
#
# NameError: name 'plt' is not defined

# %%
# 데이터 전처리
x_train = x_train/255.0;
x_test = x_test/255.0;

# %%
#모델구성
model = tf.keras.models.Sequential([
      tf.keras.layers.Flatten(input_shape=(28,28)),
      tf.keras.layers.Dense(512, activation=tf.nn.relu),
      tf.keras.layers.Dense(10, activation=tf.nn.softmax),
])
model.summary();
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# flatten_1 (Flatten)          (None, 784)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 512)               401920
# _________________________________________________________________
# dense_2 (Dense)              (None, 10)                5130
# =================================================================
# Total params: 407,050
# Trainable params: 407,050
# Non-trainable params: 0
# _________________________________________________________________

# %%
#모델 컴파일
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy',metrics=['accuracy'])

# %%
#모델 훈련
model.fit(x_train, y_train, epochs=5)
# Out:
# Epoch 1/5
# 1875/1875 [==============================] - 9s 4ms/step - loss: 0.2019 - accuracy: 0.9406
# Epoch 2/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0811 - accuracy: 0.9753
# Epoch 3/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0515 - accuracy: 0.9843
# Epoch 4/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0365 - accuracy: 0.9886
# Epoch 5/5
# 1875/1875 [==============================] - 8s 4ms/step - loss: 0.0265 - accuracy: 0.9915

# %%
#정확도평가
test_loss, test_acc=model.evaluate(x_test, y_test)
print('테스트정확도', test_acc)
# Out:
# 313/313 [==============================] - 1s 2ms/step - loss: 0.0651 - accuracy: 0.9820
# 테스트정확도 0.9819999933242798
